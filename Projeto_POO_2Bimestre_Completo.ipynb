# %% [markdown]
# # 📘 Projeto de Programação Orientada a Objetos – 2º Bimestre
#
# **Neo Lucca Viana e Silva**
#
# **2º a Ti**
#
# **Gerenciandor de humor dos alunos**

# %% [markdown]
# Lembre-se esse projeto deve ser personalizado, todas as classe e metodos devem ter uma referencia ao seu nome, exemplo:
#
# class Carro_Fabio:
#
#     def __init__(self, tipo, cor, rodas):
#         self.tipo = tipo
#         self.cor = cor
#         self.rodas = rodas
#
#     def alterar_cor_Fabio(self, nova_cor):
#         self.cor = nova_cor
#         return self.cor

# %% [markdown]
# ## PARTE 1 – Classe Principal e Objetos
#
# **Tarefas:**
# - Definir e criar a classe principal com pelo menos 3 atributos.
# - Implementar o método construtor (`__init__`).
# - Criar pelo menos 2 objetos da classe principal.
# - Implementar um método de exibição de dados.
#
# **Código:**

# %%
class Humor_Aluno_Neo:
    def __init__(self, nome, idade, humor):
        self.nome = nome
        self.idade = idade
        self.humor = humor  

    def exibir_dados_Neo(self):
        print("- DADOS DO ALUNO ")
        print(f"Nome: {self.nome}")
        print(f"Idade: {self.idade}")
        print(f"Humor: {self.humor}")
        print(" ")


aluno1 = Humor_Aluno_Neo("Japa", 16, "feliz")
aluno2 = Humor_Aluno_Neo("Samuel", 17, "estressado")

aluno1.exibir_dados_Neo()
aluno2.exibir_dados_Neo()

# %% [markdown]
# ## PARTE 2 – Métodos e Herança
#
# **Tarefas:**
# - Criar pelo menos 2 métodos de ação para a classe principal.
# - Criar uma subclasse herdando da classe principal.
# - Adicionar pelo menos 1 novo atributo e 1 novo método exclusivo na subclasse.
# - Utilizar `super()` no construtor da subclasse.
#
# **Código:**

# %%
class Humor_Aluno_Neo:
    def __init__(self, nome, idade, humor):
        self.nome = nome
        self.idade = idade
        self.humor = humor

    def exibir_dados_Neo(self):
        print(f"Nome: {self.nome} | Idade: {self.idade} | Humor: {self.humor}")

    def mudar_humor_Neo(self, novo_humor):
        self.humor = novo_humor

    def descansar_Neo(self):
        self.humor = "relaxado"

class Aluno_Especial_Neo(Humor_Aluno_Neo):
    def __init__(self, nome, idade, humor, atividade_extra):
        super().__init__(nome, idade, humor)
        self.atividade_extra = atividade_extra

    def mostrar_atividade_Neo(self):
        print(f"{self.nome} participa de: {self.atividade_extra}")


aluno1 = Humor_Aluno_Neo("João", 16, "cansado")
aluno1.descansar_Neo()
aluno1.exibir_dados_Neo()

print("")

aluno2 = Aluno_Especial_Neo("Lívia", 17, "feliz", "robótica")
aluno2.mostrar_atividade_Neo()
aluno2.exibir_dados_Neo()

# %% [markdown]
# ## PARTE 3 – Encapsulamento e Abstração
#
# **Tarefas:**
# - Tornar pelo menos 1 atributo da classe principal privado (`__atributo`).
# - Criar métodos `get` e `set` para o atributo privado.
# - Implementar um método que contenha lógica interna (ex: cálculo, verificação).
#
# **Código:**'

# %%
class Humor_Aluno_Neo:
    def __init__(self, nome, idade, humor):
        self.nome = nome
        self.idade = idade
        self.__humor = humor  

    def exibir_dados_Neo(self):
        print(f"Nome: {self.nome} | Idade: {self.idade} | Humor: {self.__humor}")


    def get_humor_Neo(self):
        return self.__humor

 
    def set_humor_Neo(self, novo_humor):
        self.__humor = novo_humor


    def verificar_humor_Neo(self):
        if self.__humor in ["triste", "estressado", "cansado"]:
            print(f"{self.nome} precisa de uma pausa!")
        else:
            print(f"{self.nome} está bem!")


aluno = Humor_Aluno_Neo("Bruna", 16, "triste")
aluno.exibir_dados_Neo()
aluno.verificar_humor_Neo()

aluno.set_humor_Neo("feliz")
print(f"Novo humor: {aluno.get_humor_Neo()}")
aluno.verificar_humor_Neo()

# %% [markdown]
# ## PARTE 4 – Polimorfismo e Banco de Dados
#
# **Tarefas:**
# - Implementar polimorfismo: sobrescrever um método na subclasse.
# - Integrar o sistema com banco de dados (MySQL ou SQLite).
# - Implementar inserção (INSERT), consulta (SELECT) e exclusão (DELETE) de registros no banco de dados.
#
# **Código:**

# %%
import sqlite3

class Humor_Aluno_Neo:
    def __init__(self, nome, idade, humor):
        self.nome = nome
        self.idade = idade
        self.humor = humor

    def exibir_dados_Neo(self):
        print(f"{self.nome} | Idade: {self.idade} | Humor: {self.humor}")

class Aluno_Especial_Neo(Humor_Aluno_Neo):
    def __init__(self, nome, idade, humor, atividade_extra):
        super().__init__(nome, idade, humor)
        self.atividade_extra = atividade_extra

    def exibir_dados_Neo(self):
        print(f"{self.nome} (Especial) | Idade: {self.idade} | Humor: {self.humor} | Atividade: {self.atividade_extra}")

con = sqlite3.connect("alunos.db")
cur = con.cursor()

cur.execute("""
CREATE TABLE IF NOT EXISTS alunos (
    nome TEXT,
    idade INTEGER,
    humor TEXT
)
""")

def inserir_aluno(nome, idade, humor):
    cur.execute("INSERT INTO alunos VALUES (?, ?, ?)", (nome, idade, humor))
    con.commit()

def listar_alunos():
    cur.execute("SELECT * FROM alunos")
    for row in cur.fetchall():
        print(row)

def deletar_aluno(nome):
    cur.execute("DELETE FROM alunos WHERE nome = ?", (nome,))
    con.commit()

inserir_aluno("Lucas", 16, "feliz")
inserir_aluno("Ana", 17, "cansada")
print("📋 Lista de Alunos:")
listar_alunos()

print("\n❌ Removendo Ana...")
deletar_aluno("Ana")

print("\n📋 Lista Atualizada:")
listar_alunos()

print("\n🎭 Polimorfismo:")
a1 = Humor_Aluno_Neo("Tiago", 16, "triste")
a2 = Aluno_Especial_Neo("Lara", 17, "feliz", "Teatro")
a1.exibir_dados_Neo()
a2.exibir_dados_Neo()

con.close()

# %% [markdown]
# ## PARTE 5 – Projeto Final e Organização
#
# **Tarefas:**
# - Consolidar todas as partes do projeto em um único script organizado.
# - Comentar o código explicando cada parte.
# - Testar todas as funcionalidades.
#
# **Código:**

# %%
# ---------------------------------------------
# PARTE 1 – Criação de Classes e Objetos
# ---------------------------------------------

class Humor_Aluno_Neo:
    def __init__(self, nome, idade, humor):
        self.__nome = nome                # Atributo privado (Encapsulamento)
        self.idade = idade
        self.humor = humor

    # ---------------------------------------------
    # PARTE 3 – Encapsulamento e Abstração
    # ---------------------------------------------

    # Getter e Setter para nome (atributo privado)
    def get_nome(self):
        return self.__nome

    def set_nome(self, novo_nome):
        if novo_nome:
            self.__nome = novo_nome

    # Método com lógica interna
    def verificar_humor(self):
        if self.humor.lower() in ["feliz", "animado"]:
            return "Dia produtivo!"
        elif self.humor.lower() in ["triste", "cansado"]:
            return "Talvez precise descansar..."
        else:
            return "Humor desconhecido."

    def exibir_dados_Neo(self):
        print(f"{self.get_nome()} | Idade: {self.idade} | Humor: {self.humor}")

# ---------------------------------------------
# PARTE 2 – Herança e Subclasses
# ---------------------------------------------

class Aluno_Especial_Neo(Humor_Aluno_Neo):
    def __init__(self, nome, idade, humor, atividade_extra):
        super().__init__(nome, idade, humor)
        self.atividade_extra = atividade_extra

    # PARTE 4 – Polimorfismo: sobrescrevendo método da superclasse
    def exibir_dados_Neo(self):
        print(f"{self.get_nome()} (Especial) | Idade: {self.idade} | Humor: {self.humor} | Atividade: {self.atividade_extra}")

# ---------------------------------------------
# PARTE 4 – Integração com Banco de Dados (SQLite)
# ---------------------------------------------
import sqlite3

# Conexão com banco (cria arquivo se não existir)
con = sqlite3.connect("alunos.db")
cur = con.cursor()

# Criar tabela
cur.execute("""
CREATE TABLE IF NOT EXISTS alunos (
    nome TEXT,
    idade INTEGER,
    humor TEXT
)
""")

# Função INSERT
def inserir_aluno(nome, idade, humor):
    cur.execute("INSERT INTO alunos VALUES (?, ?, ?)", (nome, idade, humor))
    con.commit()

# Função SELECT
def listar_alunos():
    cur.execute("SELECT * FROM alunos")
    for row in cur.fetchall():
        print(row)

# Função DELETE
def deletar_aluno(nome):
    cur.execute("DELETE FROM alunos WHERE nome = ?", (nome,))
    con.commit()

# ---------------------------------------------
# PARTE 5 – Testes Finais
# ---------------------------------------------
print("🔄 Inserindo alunos no banco:")
inserir_aluno("Lucas", 16, "feliz")
inserir_aluno("Ana", 17, "cansado")

print("\n📋 Alunos no banco:")
listar_alunos()

print("\n❌ Deletando Ana do banco...")
deletar_aluno("Ana")

print("\n📋 Alunos após exclusão:")
listar_alunos()

# Criando objetos e testando POO
print("\n🎓 Objetos e Polimorfismo:")
a1 = Humor_Aluno_Neo("Tiago", 16, "triste")
a2 = Aluno_Especial_Neo("Lara", 17, "feliz", "Teatro")

a1.exibir_dados_Neo()
print("➡️ Humor:", a1.verificar_humor())
a2.exibir_dados_Neo()
print("➡️ Humor:", a2.verificar_humor())

# Encerrando conexão com banco
con.close()
