# %% [markdown]
# # 📘 Projeto de Programação Orientada a Objetos – 2º Bimestre
#
# **Neo Lucca Viana e Silva**
#
# **2º a Ti**
#
# **Gerenciandor de humor dos alunos**

# %% [markdown]
# class Carro_Neo:
#     def __init__(self, tipo, cor, rodas):
#         self.tipo = tipo
#         self.cor = cor
#         self.rodas = rodas
#
#     def alterar_cor_Neo(self, nova_cor):
#         self.cor = nova_cor
#         return self.cor
#
#
# meu_carro = Carro_Neo("Esportivo", "Vermelho", 4)
#
# print(f"Cor original: {meu_carro.cor}")
#
#
# nova = meu_carro.alterar_cor_Neo("Azul")
# print(f"Cor após mudança: {nova}")

# %% [markdown]
# ## PARTE 1 – Classe Principal e Objetos
#
# **Tarefas:**
# - Definir e criar a classe principal com pelo menos 3 atributos.
# - Implementar o método construtor (`__init__`).
# - Criar pelo menos 2 objetos da classe principal.
# - Implementar um método de exibição de dados.
#
# **Código:**

# %%
class Humor_Aluno_Neo:
    def __init__(self, nome, idade, humor):
        self._nome = nome
        self._idade = idade
        self._humor = humor  # Ex: "feliz", "triste", "cansado", etc.

    def exibir_dados_Neo(self):
        print("----- DADOS DO ALUNO -----")
        print(f"Nome: {self._nome}")
        print(f"Idade: {self._idade}")
        print(f"Humor: {self._humor}")
        print("--------------------------\n")

# Criando dois objetos da classe principal
aluno1 = Humor_Aluno_Neo("Lucas", 16, "feliz")
aluno2 = Humor_Aluno_Neo("Ana", 17, "cansado")

# Exibindo os dados dos alunos
aluno1.exibir_dados_Neo()
aluno2.exibir_dados_Neo()

# %% [markdown]
# ## PARTE 2 – Métodos e Herança
#
# **Tarefas:**
# - Criar pelo menos 2 métodos de ação para a classe principal.
# - Criar uma subclasse herdando da classe principal.
# - Adicionar pelo menos 1 novo atributo e 1 novo método exclusivo na subclasse.
# - Utilizar `super()` no construtor da subclasse.
#
# **Código:**

# %%
class Humor_Aluno_Neo:
    def __init__(self, nome, idade, humor):
        self._nome = nome
        self._idade = idade
        self._humor = humor

    def exibir_dados_Neo(self):
        print(f"Nome: {self._nome}")
        print(f"Idade: {self._idade}")
        print(f"Humor: {self._humor}")
        print("--------------------------")

    # Método de ação 1
    def mudar_humor_Neo(self, novo_humor):
        self._humor = novo_humor
        print(f"{self._nome} teve o humor alterado para: {self._humor}")

    # Método de ação 2
    def descansar_Neo(self):
        self._humor = "relaxado"
        print(f"{self._nome} descansou e agora está: {self._humor}")


# Subclasse herdando da classe principal
class Aluno_Especial_Neo(Humor_Aluno_Neo):
    def __init__(self, nome, idade, humor, atividade_extra):
        super().__init__(nome, idade, humor)  # uso de super()
        self._atividade_extra = atividade_extra  # novo atributo exclusivo

    # Novo método exclusivo da subclasse
    def mostrar_atividade_Neo(self):
        print(f"{self._nome} participa da atividade extra: {self._atividade_extra}")


# Testando as classes
aluno1 = Humor_Aluno_Neo("Gabriel", 16, "triste")
aluno1.exibir_dados_Neo()
aluno1.descansar_Neo()
aluno1.mudar_humor_Neo("motivado")
print()

aluno2 = Aluno_Especial_Neo("Larissa", 17, "feliz", "Teatro")
aluno2.exibir_dados_Neo()
aluno2.mostrar_atividade_Neo()

# %% [markdown]
# ## PARTE 3 – Encapsulamento e Abstração
#
# **Tarefas:**
# - Tornar pelo menos 1 atributo da classe principal privado (`__atributo`).
# - Criar métodos `get` e `set` para o atributo privado.
# - Implementar um método que contenha lógica interna (ex: cálculo, verificação).
#
# **Código:**'

# %%
class Humor_Aluno_Neo:
    def __init__(self, nome, idade, humor):
        self.__nome = nome           # atributo privado
        self.__idade = idade         # atributo privado
        self.__humor = humor         # atributo privado

    # --------- MÉTODOS GET E SET ---------

    def get_nome_Neo(self):
        return self.__nome

    def get_idade_Neo(self):
        return self.__idade

    def get_humor_Neo(self):
        return self.__humor

    def set_humor_Neo(self, novo_humor):
        self.__humor = novo_humor

    # --------- MÉTODO COM LÓGICA INTERNA (ABSTRAÇÃO) ---------
    def verificar_situacao_Neo(self):
        if self.__humor == "feliz" or self.__humor == "motivado":
            return "Aluno em bom estado emocional. Pode aprender bem!"
        elif self.__humor == "triste" or self.__humor == "cansado":
            return "Aluno pode estar com baixo rendimento. Observar."
        else:
            return "Estado emocional incerto. Acompanhar mais de perto."

    def exibir_dados_Neo(self):
        print("---- DADOS DO ALUNO ----")
        print(f"Nome: {self.__nome}")
        print(f"Idade: {self.__idade}")
        print(f"Humor: {self.__humor}")
        print(f"Situação: {self.verificar_situacao_Neo()}")
        print("-------------------------\n")


# Criando e testando o objeto com verificação
aluno1 = Humor_Aluno_Neo("Eduarda", 16, "cansado")
aluno1.exibir_dados_Neo()

# Mudando o humor usando o set
aluno1.set_humor_Neo("feliz")
aluno1.exibir_dados_Neo()

# %% [markdown]
# ## PARTE 4 – Polimorfismo e Banco de Dados
#
# **Tarefas:**
# - Implementar polimorfismo: sobrescrever um método na subclasse.
# - Integrar o sistema com banco de dados (MySQL ou SQLite).
# - Implementar inserção (INSERT), consulta (SELECT) e exclusão (DELETE) de registros no banco de dados.
#
# **Código:**

# %%
import mysql.connector


conexao = mysql.connector.connect(
    host="localhost",
    user="root",               # ou outro nome de usuário
    password="",               # sua senha (pode ser vazia no XAMPP)
    database="banco_neo"       # nome do banco que você criou no MySQL
)

cursor = conexao.cursor()



class Humor_Aluno_Neo:
    def __init__(self, nome, idade, humor):
        self.nome = nome
        self.idade = idade
        self.humor = humor

    def exibir_dados_Neo(self):
        return f"{self.nome} ({self.idade} anos) - Humor: {self.humor}"

class Aluno_Especial_Neo(Humor_Aluno_Neo):
    def __init__(self, nome, idade, humor, atividade_extra):
        super().__init__(nome, idade, humor)
        self.atividade_extra = atividade_extra

    def exibir_dados_Neo(self):  # polimorfismo
        return f"{self.nome} ({self.idade} anos) - Humor: {self.humor} | Atividade: {self.atividade_extra}"



# Criar tabela (somente 1 vez)
cursor.execute("""
    CREATE TABLE IF NOT EXISTS alunos (
        id INT AUTO_INCREMENT PRIMARY KEY,
        nome VARCHAR(100),
        idade INT,
        humor VARCHAR(50),
        atividade_extra VARCHAR(100)
    )
""")

# Inserir aluno
def inserir_aluno(nome, idade, humor, atividade_extra=None):
    sql = "INSERT INTO alunos (nome, idade, humor, atividade_extra) VALUES (%s, %s, %s, %s)"
    valores = (nome, idade, humor, atividade_extra)
    cursor.execute(sql, valores)
    conexao.commit()
    print(f"✅ Aluno '{nome}' inserido com sucesso no MySQL!")

# Listar alunos
def listar_alunos():
    cursor.execute("SELECT * FROM alunos")
    resultados = cursor.fetchall()
    print("📋 Lista de alunos:")
    for aluno in resultados:
        print(aluno)

# Excluir aluno
def excluir_aluno(id):
    cursor.execute("DELETE FROM alunos WHERE id = %s", (id,))
    conexao.commit()
    print(f"❌ Aluno com ID {id} excluído do banco.")

# ------------------------------
# TESTANDO
# ------------------------------
a1 = Humor_Aluno_Neo("Bruno", 16, "triste")
a2 = Aluno_Especial_Neo("Carla", 17, "feliz", "Música")

print(a1.exibir_dados_Neo())
print(a2.exibir_dados_Neo())

inserir_aluno(a1.nome, a1.idade, a1.humor)
inserir_aluno(a2.nome, a2.idade, a2.humor, a2.atividade_extra)

listar_alunos()

# excluir_aluno(1)  # Exemplo de exclusão

conexao.close()

# %% [markdown]
# ## PARTE 5 – Projeto Final e Organização
#
# **Tarefas:**
# - Consolidar todas as partes do projeto em um único script organizado.
# - Comentar o código explicando cada parte.
# - Testar todas as funcionalidades.
#
# **Código:**

# %%
import mysql.connector


conexao = mysql.connector.connect(
    host="localhost",
    user="root",          # Altere se necessário
    password="",          # Senha, se tiver
    database="banco_neo"  # Banco criado no MySQL
)

cursor = conexao.cursor()


cursor.execute("""
CREATE TABLE IF NOT EXISTS alunos (
    id INT AUTO_INCREMENT PRIMARY KEY,
    nome VARCHAR(100),
    idade INT,
    humor VARCHAR(50),
    atividade_extra VARCHAR(100)
)
""")


class Humor_Aluno_Neo:
    def __init__(self, nome, idade, humor):
        # Encapsulamento usando atributos privados
        self.__nome = nome
        self.__idade = idade
        self.__humor = humor

    # GETs e SETs
    def get_nome(self):
        return self.__nome

    def get_idade(self):
        return self.__idade

    def get_humor(self):
        return self.__humor

    def set_humor(self, novo_humor):
        self.__humor = novo_humor

    # Método com lógica interna (Abstração)
    def verificar_situacao(self):
        if self.__humor in ["feliz", "motivado"]:
            return "Aluno pronto para aprender!"
        elif self.__humor in ["triste", "cansado"]:
            return "Aluno pode estar com rendimento baixo."
        else:
            return "Estado emocional indefinido."

    def exibir_dados(self):
        return f"{self.__nome} ({self.__idade} anos) - Humor: {self.__humor} | Situação: {self.verificar_situacao()}"


class Aluno_Especial_Neo(Humor_Aluno_Neo):
    def __init__(self, nome, idade, humor, atividade_extra):
        super().__init__(nome, idade, humor)
        self.__atividade_extra = atividade_extra

    def get_atividade_extra(self):
        return self.__atividade_extra

    # Polimorfismo: sobrescrevendo o método exibir_dados()
    def exibir_dados(self):
        return f"{self.get_nome()} ({self.get_idade()} anos) - Humor: {self.get_humor()} | Atividade: {self.__atividade_extra} | Situação: {self.verificar_situacao()}"


def inserir_aluno(nome, idade, humor, atividade_extra=None):
    cursor.execute("""
        INSERT INTO alunos (nome, idade, humor, atividade_extra)
        VALUES (%s, %s, %s, %s)
    """, (nome, idade, humor, atividade_extra))
    conexao.commit()
    print(f"✅ Aluno '{nome}' inserido no banco com sucesso!")

def listar_alunos():
    cursor.execute("SELECT * FROM alunos")
    resultados = cursor.fetchall()
    print("📋 LISTA DE ALUNOS NO BANCO:")
    for aluno in resultados:
        print(aluno)

def excluir_aluno(id):
    cursor.execute("DELETE FROM alunos WHERE id = %s", (id,))
    conexao.commit()
    print(f"❌ Aluno com ID {id} excluído do banco.")



# Criando objetos
a1 = Humor_Aluno_Neo("João", 16, "triste")
a2 = Aluno_Especial_Neo("Clara", 17, "feliz", "Música")

# Exibindo com polimorfismo e abstração
print(a1.exibir_dados())
print(a2.exibir_dados())

# Inserindo no banco
inserir_aluno(a1.get_nome(), a1.get_idade(), a1.get_humor())
inserir_aluno(a2.get_nome(), a2.get_idade(), a2.get_humor(), a2.get_atividade_extra())

# Listando
listar_alunos()

# Excluir aluno (exemplo: excluir o aluno de ID 1)
# excluir_aluno(1)

# Encerrar conexão
conexao.close()
